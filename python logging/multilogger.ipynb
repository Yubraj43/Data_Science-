# %%
import logging
from typing import Any, Dict, List, Optional
from .base import BaseModel
logger = logging.getLogger(__name__)
class ChatModel(BaseModel):
    def __init__(self, model_name: str, **kwargs: Any) -> None:
        super().__init__(model_name, **kwargs)
    def chat(self, messages: List[Dict[str, str]], **kwargs: Any) -> str:
        """
        Generate a response based on the provided messages.
        Args:
            messages (List[Dict[str, str]]): A list of messages, where each message is a dictionary with keys like 'role' and 'content'.
            **kwargs: Additional keyword arguments for the chat method.
        Returns:
            str: The generated response from the model.
        """
        raise NotImplementedError("The chat method must be implemented by subclasses of ChatModel.")
    def chat_stream(self, messages: List[Dict[str, str]], **kwargs: Any) -> Any:
        """Generate a response stream based on the provided messages.   
        Args:
            messages (List[Dict[str, str]]): A list of messages, where each message is a dictionary with keys like 'role' and 'content'.
            **kwargs: Additional keyword arguments for the chat_stream method.
        Returns:    
            Any: A stream of generated responses from the model.
        """ 
        raise NotImplementedError("The chat_stream method must be implemented by subclasses of ChatModel.")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import logging
#       2 from typing import Any, Dict, List, Optional
# ----> 3 from .base import BaseModel
#       4 logger = logging.getLogger(__name__)
#       5 class ChatModel(BaseModel):
#
# ImportError: attempted relative import with no known parent package
