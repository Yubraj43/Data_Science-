# %% [markdown]
#                                Set question for pratice

# %%
#Create an empty set. What happens if you write {} instead?
t=set()
print(t)
# Out:
# set()

# %%
#Create a set with these values: 1, 2, 2, 3, 3, 3. What is the final set?
t={1,2,2,3,3,3}
print(t)
# Out:
# {1, 2, 3}

# %%
#Take a list a = [1,2,2,3,4,4,5] and convert it to a set. Print the result.
a=[1,2,2,3,4,4,5]
s=set(a)

# %%
#Check if an element exists in a set: given s = {10, 20, 30}, check if 20 is in s
s = {10, 20, 30}
print(20 in s)
# Out:
# True

# %%
#Check if an element exists in a set: given s = {10, 20, 30}, check if 20 is in s.
s= {10, 20, 30}
if 20 in s:
    print("20 is present in the set")
else:
    print("20 is not present in the set")
# Out:
# 20 is present in the set

# %%
#Add a single element to a set (add). Example: add 99 into s.
s.add(99)
print(s)
# Out:
# {10, 99, 20, 30}

# %%
#Add multiple elements to a set (update). Example: update s with [40, 50, 60].
s.update([40, 50, 60])
print(s)
# Out:
# {99, 40, 10, 50, 20, 60, 30}

# %%
#Remove an element using remove. What error comes if the element is missing?
s.remove(10)
print(s)
# Out:
# {99, 40, 50, 20, 60, 30}

# %%
#Remove an element using discard. How is it different from remove?
s.discard(100)  # No error even if 100 is not present
print(s)
# Out:
# {99, 40, 50, 20, 60, 30}

# %%
#Pop an element from a set using pop. What does it return? Is the popped element always the same?
popped_element = s.pop()
print("Popped element:", popped_element)
# Out:
# Popped element: 99

# %%
#Given a list of numbers, find numbers that appear only once using set logic (hint: use counting or use set with another structure).
numbers = [1, 2, 2, 3, 4, 4, 5, 6, 6]
unique_numbers = set()
for num in numbers:
    if numbers.count(num) == 1:
        unique_numbers.add(num) 
print("Numbers that appear only once:", unique_numbers)
print(s)
print("Popped element:", popped_element)
print("Numbers that appear only once:", unique_numbers)
# Out:
# Numbers that appear only once: {1, 3, 5}
# {40, 50, 20, 60, 30}
# Popped element: 99
# Numbers that appear only once: {1, 3, 5}
